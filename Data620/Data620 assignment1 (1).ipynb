# %%
import networkx as nx

# %%
G=nx.Graph()
G.add_nodes_from([1,7])

# %%
G.add_edges_from([(1,2),(2,3),(2,4),(2,5),(3,4),(4,5),(3,6),(4,6),(5,6),(6,7)])

# %%
nx.draw(G)

# %%
import matplotlib.pyplot as plt
plt.show
# Out:
# <function matplotlib.pyplot.show>
